# %% [markdown]
# # Leaflet cluster map of talk locations
#
# Assuming you are working in a Linux or Windows Subsystem for Linux environment, you may need to install some dependencies. Assuming a clean installation, the following will be needed:
#
# ```bash
# sudo apt install jupyter
# sudo apt install python3-pip
# pip install python-frontmatter getorg --upgrade
# ```
#
# After which you can run this from the `_talks/` directory, via:
#
# ```bash
#  jupyter nbconvert --to notebook --execute talkmap.ipynb --output talkmap_out.ipynb
# ```
#
# The `_talks/` directory contains `.md` files of all your talks. This scrapes the location YAML field from each `.md` file, geolocates it with `geopy/Nominatim`, and uses the `getorg` library to output data, HTML, and Javascript for a standalone cluster map.

# %%
# Start by installing the dependencies
# !pip install python-frontmatter getorg --upgrade
import frontmatter
import glob
import getorg
from geopy import Nominatim
from geopy.exc import GeocoderTimedOut
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: python-frontmatter in /home/ines/.local/lib/python3.10/site-packages (1.3.0)
# Requirement already satisfied: getorg in /home/ines/.local/lib/python3.10/site-packages (0.3.1)
# Requirement already satisfied: pyyaml in /usr/lib/python3/dist-packages (from python-frontmatter) (5.4.1)
# Requirement already satisfied: retrying in /home/ines/.local/lib/python3.10/site-packages (from getorg) (1.4.2)
# Requirement already satisfied: geopy in /home/ines/.local/lib/python3.10/site-packages (from getorg) (2.4.1)
# Requirement already satisfied: pygithub in /home/ines/.local/lib/python3.10/site-packages (from getorg) (2.9.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in /home/ines/.local/lib/python3.10/site-packages (from geopy->getorg) (2.1)
# Requirement already satisfied: pyjwt[crypto]>=2.4.0 in /home/ines/.local/lib/python3.10/site-packages (from pygithub->getorg) (2.13.0)
# Requirement already satisfied: requests>=2.14.0 in /home/ines/.local/lib/python3.10/site-packages (from pygithub->getorg) (2.32.3)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/ines/.local/lib/python3.10/site-packages (from pygithub->getorg) (4.13.2)
# Requirement already satisfied: pynacl>=1.4.0 in /usr/lib/python3/dist-packages (from pygithub->getorg) (1.5.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/lib/python3/dist-packages (from pygithub->getorg) (1.26.5)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/lib/python3/dist-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (3.4.8)
# Requirement already satisfied: cffi>=1.4.1 in /home/ines/.local/lib/python3.10/site-packages (from pynacl>=1.4.0->pygithub->getorg) (1.17.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests>=2.14.0->pygithub->getorg) (2020.6.20)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ines/.local/lib/python3.10/site-packages (from requests>=2.14.0->pygithub->getorg) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.14.0->pygithub->getorg) (3.3)
# Requirement already satisfied: pycparser in /home/ines/.local/lib/python3.10/site-packages (from cffi>=1.4.1->pynacl>=1.4.0->pygithub->getorg) (2.22)
# Iywidgets and ipyleaflet support disabled. You must be in a Jupyter notebook to use this feature.
# Error raised:
# No module named 'ipywidgets'
# Check that you have enabled ipyleaflet in Jupyter with:
#     jupyter nbextension enable --py ipyleaflet

# %%
# Collect the Markdown files
g = glob.glob("_talks/*.md")

# %%
# Set the default timeout, in seconds
TIMEOUT = 5

# Prepare to geolocate
geocoder = Nominatim(user_agent="academicpages.github.io")
location_dict = {}
location = ""
permalink = ""
title = ""

# %% [markdown]
# In the event that this times out with an error, double check to make sure that the location is can be properly geolocated.

# %%
# Perform geolocation
for file in g:
    # Read the file
    data = frontmatter.load(file)
    data = data.to_dict()

    # Press on if the location is not present
    if 'location' not in data:
        continue

    # Prepare the description
    title = data['title'].strip()
    venue = data['venue'].strip()
    location = data['location'].strip()
    description = f"{title}<br />{venue}; {location}"

    # Geocode the location and report the status
    try:
        location_dict[description] = geocoder.geocode(location, timeout=TIMEOUT)
        print(description, location_dict[description])
    except ValueError as ex:
        print(f"Error: geocode failed on input {location} with message {ex}")
    except GeocoderTimedOut as ex:
        print(f"Error: geocode timed out on input {location} with message {ex}")
    except Exception as ex:
        print(f"An unhandled exception occurred while processing input {location} with message {ex}")
# Out:
# Fast Geometric Machine Learning Methods for Brain Image Analysis<br />Reasearch Team Meetings and Seminars; Paris, Fr Paris, Île-de-France, France métropolitaine, France
# ISBI Conference Proceeding talk<br />IEEE 23rd International Symposium on Biomedical Imaging (ISBI); London, UK Greater London, England, United Kingdom

# %%
# Save the map
m = getorg.orgmap.create_map_obj()
getorg.orgmap.output_html_cluster_map(location_dict, folder_name="talkmap", hashed_usernames=False)
# Out:
# 'Written map to talkmap/'
